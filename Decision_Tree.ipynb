# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DecisionTree.csv')

# %%
df.head()
# Out:
#    Age  Experience  Rank Nationality   Go
# 0   36          10     9          UK   NO
# 1   42          12     4         USA   NO
# 2   23           4     6           N   NO
# 3   52           4     4         USA   NO
# 4   43          21     8         USA  YES

# %%
#Change string values into numerical values
d = {'UK': 0, 'USA': 1, 'N': 2}
df['Nationality'] = df['Nationality'].map(d)
d = {'YES': 1, 'NO': 0}
df['Go'] = df['Go'].map(d)

# %%
df.head()
# Out:
#    Age  Experience  Rank  Nationality  Go
# 0   36          10     9            0   0
# 1   42          12     4            1   0
# 2   23           4     6            2   0
# 3   52           4     4            1   0
# 4   43          21     8            1   1

# %%
#X is the feature columns, y is the target column
features = ['Age', 'Experience', 'Rank', 'Nationality']

x = df[features]
y = df['Go']

# %%
import pandas
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(x=df['Age'],y=df['Rank'])
# Out:
# <Axes: xlabel='Age', ylabel='Rank'>

# %%
sns.countplot(df.Go)
# Out:
# <Axes: ylabel='count'>

# %%
df.Go.value_counts()
# Out:
# 1    7
# 0    6
# Name: Go, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.75, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-1.33630621, -0.70710678, -0.26726124, -0.70710678],
#        [ 0.26726124,  1.41421356, -1.06904497, -0.70710678],
#        [ 1.06904497, -0.70710678,  1.33630621,  1.41421356]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
log = LogisticRegression()

# %%
log.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred1= log.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred1)
# Out:
# 0.6

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
precision_score(y_test, y_pred1)
# Out:
# 1.0

# %%
recall_score(y_test, y_pred1)
# Out:
# 0.3333333333333333

# %%
f1_score(y_test, y_pred1)
# Out:
# 0.5

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2= dt.predict(x_test)

# %%
accuracy_score(y_test, y_pred2)
# Out:
# 0.5

# %%
precision_score(y_test, y_pred2)
# Out:
# 0.6666666666666666
