# %% [markdown]
# # Pokemon Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/pokemon.csv')
df.head()
# Out:
#    Unnamed: 0                                          image_url  Id  \
# 0           0  https://img.pokemondb.net/sprites/sword-shield...   1
# 1           1  https://img.pokemondb.net/sprites/sword-shield...   2
# 2           2  https://img.pokemondb.net/sprites/sword-shield...   3
# 3           3  https://img.pokemondb.net/sprites/sword-shield...   3
# 4           4  https://img.pokemondb.net/sprites/sword-shield...   4
#
#                     Names  Type1   Type2  Total  HP  Attack  Defense  Sp. Atk  \
# 0               Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                 Ivysaur  Grass  Poison    405  60      62       63       80
# 2                Venusaur  Grass  Poison    525  80      82       83      100
# 3  Venusaur Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4              Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed
# 0       65     45
# 1       80     60
# 2      100     80
# ...

# %%
df[df["Type2"].isna()]
# Out:
#       Unnamed: 0                                          image_url   Id  \
# 4              4  https://img.pokemondb.net/sprites/sword-shield...    4
# 5              5  https://img.pokemondb.net/sprites/sword-shield...    5
# 9              9  https://img.pokemondb.net/sprites/sword-shield...    7
# 10            10  https://img.pokemondb.net/sprites/sword-shield...    8
# 11            11  https://img.pokemondb.net/sprites/sword-shield...    9
# ...          ...                                                ...  ...
# 1156        1156  https://img.pokemondb.net/sprites/scarlet-viol...  977
# 1163        1163  https://img.pokemondb.net/sprites/scarlet-viol...  982
# 1164        1164  https://img.pokemondb.net/sprites/scarlet-viol...  982
# 1181        1181  https://img.pokemondb.net/sprites/scarlet-viol...  999
# 1182        1182  https://img.pokemondb.net/sprites/scarlet-viol...  999
#
#                                Names   Type1 Type2  Total   HP  Attack  \
# ...

# %%
df.fillna("None")
# Out:
#       Unnamed: 0                                          image_url    Id  \
# 0              0  https://img.pokemondb.net/sprites/sword-shield...     1
# 1              1  https://img.pokemondb.net/sprites/sword-shield...     2
# 2              2  https://img.pokemondb.net/sprites/sword-shield...     3
# 3              3  https://img.pokemondb.net/sprites/sword-shield...     3
# 4              4  https://img.pokemondb.net/sprites/sword-shield...     4
# ...          ...                                                ...   ...
# 1189        1189  https://img.pokemondb.net/sprites/scarlet-viol...  1006
# 1190        1190  https://img.pokemondb.net/sprites/scarlet-viol...  1007
# 1191        1191  https://img.pokemondb.net/sprites/scarlet-viol...  1008
# 1192        1192  https://img.pokemondb.net/sprites/scarlet-viol...  1009
# 1193        1193  https://img.pokemondb.net/sprites/scarlet-viol...  1010
#
#                        Names     Type1     Type2  Total   HP  Attack  Defense  \
# ...

# %%
# df[df['Type2']=='None']['Type2']
df[df['Type1'] == 'Fire'].count()
# Out:
# Unnamed: 0    75
# image_url     75
# Id            75
# Names         75
# Type1         75
# Type2         38
# Total         75
# HP            75
# Attack        75
# Defense       75
# Sp. Atk       75
# Sp. Def       75
# Speed         75
# dtype: int64

# %%
df[df["Speed"] == 200]
# Out:
#       Unnamed: 0                                          image_url   Id  \
# 1063        1063  https://img.pokemondb.net/sprites/sword-shield...  894
#
#           Names     Type1 Type2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 1063  Regieleki  Electric   NaN    580  80     100       50      100       50
#
#       Speed
# 1063    200

# %%
# max(df['Speed'])
df.Speed.max()
# Out:
# 200

# %%
df[df['Speed'] == min(df['Speed'])]
# Out:
#      Unnamed: 0                                          image_url   Id  \
# 272         272  https://img.pokemondb.net/sprites/sword-shield...  213
# 546         546  https://img.pokemondb.net/sprites/sword-shield...  446
# 928         928  https://img.pokemondb.net/sprites/sword-shield...  771
#
#          Names   Type1 Type2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 272    Shuckle     Bug  Rock    505   20      10      230       10      230
# 546   Munchlax  Normal   NaN    390  135      85       40       40       85
# 928  Pyukumuku   Water   NaN    410   55      60      130       30      130
#
#      Speed
# 272      5
# 546      5
# 928      5

# %%
max(df['Attack'])
# Out:
# 190

# %%
df[1:6][['Names','Attack','Type1']]
# Out:
#                     Names  Attack  Type1
# 1                 Ivysaur      62  Grass
# 2                Venusaur      82  Grass
# 3  Venusaur Mega Venusaur     100  Grass
# 4              Charmander      52   Fire
# 5              Charmeleon      64   Fire

# %%
e = df[df['Type1'] == 'Electric']
e[e['Attack']==e['Attack'].max()]
# Out:
#      Unnamed: 0                                          image_url   Id  \
# 568         568  https://img.pokemondb.net/sprites/sword-shield...  466
#
#           Names     Type1 Type2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 568  Electivire  Electric   NaN    540  75     123       67       95       85
#
#      Speed
# 568     95

# %%
df.sort_values("Defense",inplace=True)
df
# Out:
#       Unnamed: 0                                          image_url   Id  \
# 151          151  https://img.pokemondb.net/sprites/sword-shield...  113
# 539          539  https://img.pokemondb.net/sprites/sword-shield...  440
# 305          305  https://img.pokemondb.net/sprites/sword-shield...  242
# 301          301  https://img.pokemondb.net/sprites/sword-shield...  238
# 227          227  https://img.pokemondb.net/sprites/sword-shield...  174
# ...          ...                                                ...  ...
# 966          966  https://img.pokemondb.net/sprites/sword-shield...  805
# 272          272  https://img.pokemondb.net/sprites/sword-shield...  213
# 379          379  https://img.pokemondb.net/sprites/sword-shield...  306
# 265          265  https://img.pokemondb.net/sprites/sword-shield...  208
# 1058        1058  https://img.pokemondb.net/sprites/sword-shield...  890
#
#                      Names   Type1    Type2  Total   HP  Attack  Defense  \
# ...

# %%
df.sort_values("Speed",inplace=True)
df
# Out:
#       Unnamed: 0                                          image_url   Id  \
# 546          546  https://img.pokemondb.net/sprites/sword-shield...  446
# 272          272  https://img.pokemondb.net/sprites/sword-shield...  213
# 928          928  https://img.pokemondb.net/sprites/sword-shield...  771
# 990          990  https://img.pokemondb.net/sprites/sword-shield...  829
# 1181        1181  https://img.pokemondb.net/sprites/scarlet-viol...  999
# ...          ...                                                ...  ...
# 136          136  https://img.pokemondb.net/sprites/scarlet-viol...  101
# 953          953  https://img.pokemondb.net/sprites/sword-shield...  795
# 361          361  https://img.pokemondb.net/sprites/sword-shield...  291
# 480          480  https://img.pokemondb.net/sprites/sword-shield...  386
# 1063        1063  https://img.pokemondb.net/sprites/sword-shield...  894
#
#                             Names     Type1     Type2  Total   HP  Attack  \
# ...

# %%
df.sort_values("Speed", ascending= False, inplace=True)
df
# Out:
#       Unnamed: 0                                          image_url   Id  \
# 1063        1063  https://img.pokemondb.net/sprites/sword-shield...  894
# 480          480  https://img.pokemondb.net/sprites/sword-shield...  386
# 361          361  https://img.pokemondb.net/sprites/sword-shield...  291
# 953          953  https://img.pokemondb.net/sprites/sword-shield...  795
# 477          477  https://img.pokemondb.net/sprites/sword-shield...  386
# ...          ...                                                ...  ...
# 721          721  https://img.pokemondb.net/sprites/sword-shield...  597
# 990          990  https://img.pokemondb.net/sprites/sword-shield...  829
# 546          546  https://img.pokemondb.net/sprites/sword-shield...  446
# 272          272  https://img.pokemondb.net/sprites/sword-shield...  213
# 928          928  https://img.pokemondb.net/sprites/sword-shield...  771
#
#                     Names     Type1     Type2  Total   HP  Attack  Defense  \
# ...

# %%
df.sort_values(["Type1","Type2"], inplace=True)
filter1 = df["Type1"]== "Bug"
filter2 = df["Type2"]=="Electric"
e1=df.where(filter1 & filter2)
e1
# Out:
#       Unnamed: 0                                          image_url     Id  \
# 1094         NaN                                                NaN    NaN
# 720        720.0  https://img.pokemondb.net/sprites/sword-shield...  596.0
# 719        719.0  https://img.pokemondb.net/sprites/sword-shield...  595.0
# 888        888.0  https://img.pokemondb.net/sprites/sword-shield...  738.0
# 887        887.0  https://img.pokemondb.net/sprites/sword-shield...  737.0
# ...          ...                                                ...    ...
# 1156         NaN                                                NaN    NaN
# 520          NaN                                                NaN    NaN
# 450          NaN                                                NaN    NaN
# 903          NaN                                                NaN    NaN
# 928          NaN                                                NaN    NaN
#
# ...

# %%
df["Type1"].value_counts()
# Out:
# Water       150
# Normal      131
# Grass       105
# Bug          91
# Psychic      82
# Fire         75
# Electric     73
# Rock         67
# Dark         56
# Fighting     50
# Dragon       49
# Ghost        47
# Ground       46
# Poison       45
# Ice          43
# Steel        43
# Fairy        31
# Flying       10
# Name: Type1, dtype: int64

# %%
df["Type2"].value_counts()
# Out:
# Flying      122
# Psychic      49
# Poison       47
# Ground       43
# Fairy        42
# Fighting     41
# Steel        40
# Dragon       39
# Ghost        37
# Dark         33
# Grass        33
# Water        25
# Ice          22
# Fire         20
# Rock         19
# Normal       18
# Electric     13
# Bug           9
# Name: Type2, dtype: int64

# %%
df["Speed"].value_counts()
# Out:
# 50     62
# 60     61
# 65     54
# 70     52
# 30     51
#        ..
# 26      1
# 143     1
# 200     1
# 142     1
# 22      1
# Name: Speed, Length: 127, dtype: int64

# %%
df["Attack"].value_counts()
# Out:
# 100    65
# 65     56
# 80     52
# 85     50
# 75     49
#        ..
# 147     1
# 31      1
# 97      1
# 116     1
# 15      1
# Name: Attack, Length: 126, dtype: int64

# %%
df
# Out:
#       Unnamed: 0                                          image_url   Id  \
# 1094        1094  https://img.pokemondb.net/sprites/scarlet-viol...  920
# 720          720  https://img.pokemondb.net/sprites/sword-shield...  596
# 719          719  https://img.pokemondb.net/sprites/sword-shield...  595
# 888          888  https://img.pokemondb.net/sprites/sword-shield...  738
# 887          887  https://img.pokemondb.net/sprites/sword-shield...  737
# ...          ...                                                ...  ...
# 1156        1156  https://img.pokemondb.net/sprites/scarlet-viol...  977
# 520          520  https://img.pokemondb.net/sprites/sword-shield...  422
# 450          450  https://img.pokemondb.net/sprites/sword-shield...  366
# 903          903  https://img.pokemondb.net/sprites/sword-shield...  746
# 928          928  https://img.pokemondb.net/sprites/sword-shield...  771
#
#                        Names  Type1     Type2  Total   HP  Attack  Defense  \
# ...

# %%
e=df[df['Type1']=='Ice']
e['Names']
# Out:
# 1035                             Frosmoth
# 1034                                 Snom
# 51             Ninetales Alolan Ninetales
# 676          Darmanitan Galarian Zen Mode
# 191                              Articuno
# 287                              Delibird
# 581                              Froslass
# 575                             Mamoswine
# 282                             Piloswine
# 281                                Swinub
# 162            Mr. Mime Galarian Mr. Mime
# 164                                  Jynx
# 1028                             Mr. Rime
# 301                              Smoochum
# 858               Avalugg Hisuian Avalugg
# 39             Sandslash Alolan Sandslash
# 37             Sandshrew Alolan Sandshrew
# 1173                          Iron Bundle
# 449                               Walrein
# 448                                Sealeo
# 447                                Spheal
# 1038                    Eiscue Noice Face
# ...

# %%
df.loc[(df.Type1 == "Flying")][["Names","Type2"]]
# Out:
#                          Names     Type2
# 1140                Bombirdier      Dark
# 860                    Noivern    Dragon
# 859                     Noibat    Dragon
# 1152                   Flamigo  Fighting
# 984                Corviknight     Steel
# 1006                 Cramorant     Water
# 768     Tornadus Therian Forme       NaN
# 767   Tornadus Incarnate Forme       NaN
# 983                Corvisquire       NaN
# 982                   Rookidee       NaN

# %%
df.loc[(df.Type1 == "Steel")][['Names','Speed']]
# Out:
#                          Names  Speed
# 592        Dialga Origin Forme     90
# 591                     Dialga     90
# 1049                 Duraludon     85
# 844      Goodra Hisuian Goodra     60
# 842    Sliggoo Hisuian Sliggoo     40
# 845                     Klefki     75
# 962                   Magearna     65
# 375         Mawile Mega Mawile     50
# 374                     Mawile     50
# 764                   Cobalion    108
# 289                   Skarmory     70
# 955                 Celesteela     61
# 1183                 Gholdengo     84
# 817      Aegislash Blade Forme     60
# 816     Aegislash Shield Forme     60
# 815                   Doublade     35
# 814                    Honedge     28
# 264                    Steelix     30
# 265       Steelix Mega Steelix     30
# 1145                 Revavroom     90
# 1144                    Varoom     47
# 462   Metagross Mega Metagross    110
# 476                    Jirachi    100
# 461                  Metagross     70
# ...

# %%
df.loc[(df.Attack.max())][['Names','Type1','Type2']]
# Out:
# Names    Snorlax
# Type1     Normal
# Type2        NaN
# Name: 190, dtype: object

# %%
#Find Names Type1 and Type2 pokemons where attack is maximum
df.loc[df.Attack== df.Attack.max()][['Names','Type1','Type2']]
# Out:
#                     Names    Type1     Type2
# 201  Mewtwo Mega Mewtwo X  Psychic  Fighting

# %%
df.loc[df["Attack"]== df["Attack"].min()][['Names','Type1','Type2']]
# Out:
#        Names   Type1 Type2
# 151  Chansey  Normal   NaN
# 539  Happiny  Normal   NaN

# %%
df.loc[df["Defense"]== df["Defense"].min()][['Names','Type1','Type2']]
# Out:
#        Names   Type1 Type2
# 151  Chansey  Normal   NaN
# 539  Happiny  Normal   NaN

# %%
df.loc[df["Defense"]== df["Defense"].max()][['Names','Type1','Type2']]
# Out:
#                     Names   Type1   Type2
# 1058  Eternatus Eternamax  Poison  Dragon

# %%
plt.plot(df['Attack'], color = 'black')

# %%
df.loc[df.Attack.max() & df.Defense.max()][['Names', 'Defense', 'Attack']]
# Out:
# Names      Kabuto
# Defense        90
# Attack         80
# Name: 186, dtype: object

# %%
e = df[df['Defense']>150]
e[e['Attack'] > 150]
# Out:
#      Unnamed: 0                                          image_url   Id  \
# 473         473  https://img.pokemondb.net/sprites/sword-shield...  383
#
#                       Names   Type1 Type2  Total   HP  Attack  Defense  \
# 473  Groudon Primal Groudon  Ground  Fire    770  100     180      160
#
#      Sp. Atk  Sp. Def  Speed
# 473      150       90     90

# %%
import numpy as np
x = np.array([0,6])
y=np.array([0,250])
plt.plot(x,y, ls='-.', color='#000')

plt.show()

# %%
x1 = np.array([0,1,2,3])
y1 = np.array([3,8,1,10])
# x2 = np.array([0,1,2,3])
# y2 = np.array([6,2,7,10])
plt.scatter(x1,y1)
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.grid()
plt.show()

# %%
df.head()
# Out:
#       Unnamed: 0                                          image_url   Id  \
# 1094        1094  https://img.pokemondb.net/sprites/scarlet-viol...  920
# 720          720  https://img.pokemondb.net/sprites/sword-shield...  596
# 719          719  https://img.pokemondb.net/sprites/sword-shield...  595
# 888          888  https://img.pokemondb.net/sprites/sword-shield...  738
# 887          887  https://img.pokemondb.net/sprites/sword-shield...  737
#
#            Names Type1     Type2  Total  HP  Attack  Defense  Sp. Atk  \
# 1094       Lokix   Bug      Dark    450  71     102       78       52
# 720   Galvantula   Bug  Electric    472  70      77       60       97
# 719       Joltik   Bug  Electric    319  50      47       50       57
# 888     Vikavolt   Bug  Electric    500  77      70       90      145
# 887    Charjabug   Bug  Electric    400  57      82       95       55
#
#       Sp. Def  Speed
# 1094       55     92
# 720        60    108
# 719        50     65
# ...

# %%
df.loc[df.Total == df.Total.max()]
# Out:
#       Unnamed: 0                                          image_url   Id  \
# 1058        1058  https://img.pokemondb.net/sprites/sword-shield...  890
#
#                     Names   Type1   Type2  Total   HP  Attack  Defense  \
# 1058  Eternatus Eternamax  Poison  Dragon   1125  255     115      250
#
#       Sp. Atk  Sp. Def  Speed
# 1058      125      250    130

# %% [markdown]
# # New Dataset

# %%
#Dataset
#day 1 to 7
#impressions: [10,15,12,18,20,15,21]
#clicks [2,3,4,5,3,5,4]

data = {
    "Days" : [1,2,3,4,5,6,7],
    "Impressions": [10,15,12,18,20,15,21],
    "Clicks": [2,3,4,5,3,5,4]
}
newdata = pd.DataFrame(data)
newdata
# Out:
#    Days  Impressions  Clicks
# 0     1           10       2
# 1     2           15       3
# 2     3           12       4
# 3     4           18       5
# 4     5           20       3
# 5     6           15       5
# 6     7           21       4

# %%
plt.pie(newdata["Clicks"])
plt.plot(newdata["Impressions"])
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

# %%
df.loc[df.Total == df.Total.max()]
# Out:
#       Unnamed: 0                                          image_url   Id  \
# 1058        1058  https://img.pokemondb.net/sprites/sword-shield...  890
#
#                     Names   Type1   Type2  Total   HP  Attack  Defense  \
# 1058  Eternatus Eternamax  Poison  Dragon   1125  255     115      250
#
#       Sp. Atk  Sp. Def  Speed
# 1058      125      250    130

# %%
plt.plot(df.Speed)

# %%
# df.sort_values(by = 'Speed', ascending= False)
# filter1 = df.Type2 == 'Grass'
# e3= df.where(filter1)
# e3
w=df.loc[df.Type1 == 'Fairy']
w.sort_values("Attack", inplace = True)
w.Attack
x = np.arange(len(w))
plt.grid()
plt.plot(x,w['Attack'], marker='o')
# Out:
# <ipython-input-40-d2336438fcb9>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w.sort_values("Attack", inplace = True)

# %%
df[df.Names.str[0]=='G']
# Out:
#      Unnamed: 0                                          image_url   Id  \
# 720         720  https://img.pokemondb.net/sprites/sword-shield...  596
# 782         782  https://img.pokemondb.net/sprites/sword-shield...  649
# 925         925  https://img.pokemondb.net/sprites/sword-shield...  768
# 886         886  https://img.pokemondb.net/sprites/sword-shield...  736
# 957         957  https://img.pokemondb.net/sprites/sword-shield...  799
# ..          ...                                                ...  ...
# 174         174  https://img.pokemondb.net/sprites/sword-shield...  130
# 521         521  https://img.pokemondb.net/sprites/sword-shield...  423
# 73           73  https://img.pokemondb.net/sprites/sword-shield...   55
# 157         157  https://img.pokemondb.net/sprites/sword-shield...  118
# 452         452  https://img.pokemondb.net/sprites/sword-shield...  368
#
#           Names  Type1     Type2  Total   HP  Attack  Defense  Sp. Atk  \
# ...

# %%
df[df['Defense'].between(5,15)]
# Out:
#      Unnamed: 0                                          image_url   Id  \
# 225         225  https://img.pokemondb.net/sprites/sword-shield...  172
# 301         301  https://img.pokemondb.net/sprites/sword-shield...  238
# 227         227  https://img.pokemondb.net/sprites/sword-shield...  174
# 305         305  https://img.pokemondb.net/sprites/sword-shield...  242
# 151         151  https://img.pokemondb.net/sprites/sword-shield...  113
# 539         539  https://img.pokemondb.net/sprites/sword-shield...  440
# 83           83  https://img.pokemondb.net/sprites/sword-shield...   63
#
#          Names     Type1    Type2  Total   HP  Attack  Defense  Sp. Atk  \
# 225      Pichu  Electric      NaN    205   20      40       15       35
# 301   Smoochum       Ice  Psychic    305   45      30       15       85
# 227  Igglybuff    Normal    Fairy    210   90      30       15       40
# 305    Blissey    Normal      NaN    540  255      10       10       75
# ...

# %%
f=df[df.Type2 == 'Fire']
f[df['Type1']=='Ground']
# Out:
# <ipython-input-43-990a879c18e2>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   f[df['Type1']=='Ground']
#      Unnamed: 0                                          image_url   Id  \
# 473         473  https://img.pokemondb.net/sprites/sword-shield...  383
#
#                       Names   Type1 Type2  Total   HP  Attack  Defense  \
# 473  Groudon Primal Groudon  Ground  Fire    770  100     180      160
#
#      Sp. Atk  Sp. Def  Speed
# 473      150       90     90
