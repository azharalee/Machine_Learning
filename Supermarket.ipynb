# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Supermarket.xlsx')

# %%
df.head()
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.102  107.142  2019-09-03 00:00:00  17:03:00
# 3       93.72         6  28.116  590.436            1/15/2019  16:19:00
# 4       40.30         2   4.030   84.630  2019-11-03 00:00:00  15:30:00
#
# ...

# %%
df.Payment.value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
df['City'].value_counts()
# Out:
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64

# %%
df['City'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='City'>

# %%
df.loc[df['Payment'] == 'Cash']
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 2    529-56-3974      B  Mandalay        Member    Male
# 3    299-46-1805      B  Mandalay        Member  Female
# 7    649-29-6775      B  Mandalay        Normal    Male
# 8    145-94-9061      B  Mandalay        Normal  Female
# 10   149-71-6266      B  Mandalay        Member    Male
# ..           ...    ...       ...           ...     ...
# 992  221-25-5073      A    Yangon        Normal  Female
# 993  809-46-1866      A    Yangon        Normal    Male
# 997  727-02-1313      A    Yangon        Member    Male
# 998  347-56-2442      A    Yangon        Normal    Male
# 999  849-09-3807      A    Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 2    Electronic_accessories       25.51         4   5.1020  107.1420
# 3         Sports_and_travel       93.72         6  28.1160  590.4360
# 7       Fashion_accessories       33.52         1   1.6760   35.1960
# ...

# %%
df['Customer type'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Customer type'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='Customer type'>

# %%
df[df['Branch'] == 'B']['Rating'].mode()
# Out:
# 0    5.1
# 1    6.5
# 2    8.9
# Name: Rating, dtype: float64

# %%
df['Branch'].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
df['Branch'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
e=df[df['Gender'] == 'Male']
e[e['Customer type'] == 'Member']
# Out:
#       Invoice ID Branch      City Customer type Gender  \
# 2    529-56-3974      B  Mandalay        Member   Male
# 10   149-71-6266      B  Mandalay        Member   Male
# 12   777-82-7220      B  Mandalay        Member   Male
# 16   370-41-7321      B  Mandalay        Member   Male
# 18   669-54-1719      B  Mandalay        Member   Male
# ..           ...    ...       ...           ...    ...
# 972  522-57-8364      A    Yangon        Member   Male
# 982  333-23-2632      A    Yangon        Member   Male
# 986  324-92-3863      A    Yangon        Member   Male
# 989  195-06-0432      A    Yangon        Member   Male
# 997  727-02-1313      A    Yangon        Member   Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 2    Electronic_accessories       25.51         4   5.1020  107.1420
# 10        Sports_and_travel       78.07         9  35.1315  737.7615
# 12       Home_and_lifestyle       30.12         8  12.0480  253.0080
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df['Total'].median()
# Out:
# 253.848

# %%
df.loc[df['Rating'] == df['Rating'].max()]['Product line']
# Out:
# 21          Sports_and_travel
# 48          Sports_and_travel
# 279    Electronic_accessories
# 347         Sports_and_travel
# 794         Health_and_beauty
# Name: Product line, dtype: object

# %%
df.groupby(['Gender','Payment']).count()['Quantity']
# Out:
# Gender  Payment
# Female  Cash           178
#         Credit card    163
#         Ewallet        160
# Male    Cash           166
#         Credit card    148
#         Ewallet        185
# Name: Quantity, dtype: int64

# %%
df.groupby(['Branch','City','Customer type']).count()
# Out:
#                                 Invoice ID  Gender  Product line  Unit price  \
# Branch City      Customer type
# A      Yangon    Member                167     167           167         167
#                  Normal                173     173           173         173
# B      Mandalay  Member                165     165           165         165
#                  Normal                167     167           167         167
# C      Naypyitaw Member                169     169           169         169
#                  Normal                159     159           159         159
#
#                                 Quantity  Tax 5%  Total  Date  Time  Payment  \
# Branch City      Customer type
# A      Yangon    Member              167     167    167   167   167      167
#                  Normal              173     173    173   173   173      173
# B      Mandalay  Member              165     165    165   165   165      165
# ...

# %%
df.groupby(['Branch','City']).count()
# Out:
#                   Invoice ID  Customer type  Gender  Product line  Unit price  \
# Branch City
# A      Yangon            340            340     340           340         340
# B      Mandalay          332            332     332           332         332
# C      Naypyitaw         328            328     328           328         328
#
#                   Quantity  Tax 5%  Total  Date  Time  Payment  cogs  \
# Branch City
# A      Yangon          340     340    340   340   340      340   340
# B      Mandalay        332     332    332   332   332      332   332
# C      Naypyitaw       328     328    328   328   328      328   328
#
#                   gross margin percentage  gross income  Rating
# Branch City
# A      Yangon                         340           340     340
# B      Mandalay                       332           332     332
# C      Naypyitaw                      328           328     328

# %%
df.groupby(['Customer type','Gender']).count()['Product line']
# Out:
# Customer type  Gender
# Member         Female    261
#                Male      240
# Normal         Female    240
#                Male      259
# Name: Product line, dtype: int64

# %%
df.groupby(['Gender','Payment']).agg(['count','sum','min','max'])['Quantity']
# Out:
# <ipython-input-22-f6b5f9945c45>:1: FutureWarning: ['Date', 'Time'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby(['Gender','Payment']).agg(['count','sum','min','max'])['Quantity']
#                     count   sum  min  max
# Gender Payment
# Female Cash           178  1004    1   10
#        Credit card    163   928    1   10
#        Ewallet        160   937    1   10
# Male   Cash           166   892    1   10
#        Credit card    148   794    1   10
#        Ewallet        185   955    1   10

# %%
#date and time
#type of graph
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df['Date']
# Out:
# 0                2/20/2019
# 1      2019-06-02 00:00:00
# 2      2019-09-03 00:00:00
# 3                1/15/2019
# 4      2019-11-03 00:00:00
#               ...
# 995              3/22/2019
# 996    2019-10-03 00:00:00
# 997    2019-09-02 00:00:00
# 998              2/22/2019
# 999              2/18/2019
# Name: Date, Length: 1000, dtype: object

# %%
data = pd.date_range('1/1/2011', periods = 10, freq ='H')

x = pd.datetime.now()
x.month, x.year
# Out:
# <ipython-input-54-d6c66599d386>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   x = pd.datetime.now()
# (8, 2023)

# %%
df.head()
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.102  107.142  2019-09-03 00:00:00  17:03:00
# 3       93.72         6  28.116  590.436            1/15/2019  16:19:00
# 4       40.30         2   4.030   84.630  2019-11-03 00:00:00  15:30:00
#
# ...

# %%
df.Gender.value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
import seaborn as sns
sns.countplot(x=df['Gender'])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x=df['City'])
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
sns.countplot(x='Product line', data=df, hue='Gender',hue_order=['Male', 'Female'], order=['Electronic_accessories','Food_and_beverages', 'Fashion_accessories','Sports_and_travel','Home_and_lifestyle', 'Health_and_beauty'])
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line', y='Total', data=df, hue='Payment', hue_order=['Ewallet','Credit card', 'Cash'],order=['Electronic_accessories','Food_and_beverages', 'Fashion_accessories','Sports_and_travel','Home_and_lifestyle', 'Health_and_beauty'])
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Product line',data=df, hue='Gender', facecolor='#fff', linewidth= 10, edgecolor=sns.color_palette('dark',3))
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='Payment',data=df, hue='Gender', palette='PuBuGn_r')
# Out:
# <Axes: xlabel='Payment', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='Product line', y='Total', data=df, hue='Gender')
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='Customer type', y='Rating', data=df, hue='Gender')
# Out:
# <Axes: xlabel='Customer type', ylabel='Rating'>

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='City', y='Quantity', data=df, hue='Payment')
# Out:
# <Axes: xlabel='City', ylabel='Quantity'>

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Branch', y='Total', data=df, hue='Payment')
# Out:
# <Axes: xlabel='Branch', ylabel='Total'>

# %%
df.head()
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.102  107.142  2019-09-03 00:00:00  17:03:00
# 3       93.72         6  28.116  590.436            1/15/2019  16:19:00
# 4       40.30         2   4.030   84.630  2019-11-03 00:00:00  15:30:00
#
# ...

# %%
df['Product line'].unique()
# Out:
# array(['Food_and_beverages', 'Fashion_accessories',
#        'Electronic_accessories', 'Sports_and_travel',
#        'Home_and_lifestyle', 'Health_and_beauty'], dtype=object)

# %%
sns.boxplot(y='Total', data=df, width=0.2, showmeans=True, meanprops={'marker':'o'})
# Out:
# <Axes: ylabel='Total'>

# %%
df.Total.mean()
# Out:
# 322.966749

# %%
sns.boxplot(y='cogs', data=df, width=0.2, showmeans=True, meanprops={'marker':'o', 'markerfacecolor':'white', 'markersize':10})
# Out:
# <Axes: ylabel='cogs'>

# %%
df.cogs.mean()
# Out:
# 307.58738

# %%
sns.boxplot(x='Payment', y='Total', data=df, hue='Gender')
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='Product line', y='Rating', data=df, hue='Payment', showmeans=True)
# Out:
# <Axes: xlabel='Product line', ylabel='Rating'>

# %%
df.Payment.value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
plt.figure(figsize = (12,8))
sns.violinplot(x='Payment',y='Total', data=df,hue='Gender', split=True,palette="muted", inner='quartile')
sns.boxplot(x='Payment',y='Total', data=df,hue='Gender',palette="muted")
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
sns.stripplot(y='Total', x='Payment', data=df, hue='Payment', palette="deep")
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
sns.stripplot(y='Total', x='Payment', data=df, hue='Gender', palette="deep")
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
plt.figure(figsize = (12,8))
sns.stripplot(y='Total', x='Product line', data=df,hue='Customer type',palette="deep", dodge=True,jitter=False, s=10, marker="D", linewidth=1, alpha=.5,)
# sns.boxplot(x='Total',y='Product line', data=df,hue='Customer type',palette="muted")
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
df[df['Product line'] == 'Food_and_beverages']['Total'].sum()
# Out:
# 56144.844

# %%
df['Customer type'].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
plt.figure(figsize = (12,8))
sns.stripplot(y='Total', x='Product line', data=df,hue='Customer type', dodge=True, palette='muted')
sns.boxplot(y='Total',x='Product line', data=df,hue='Customer type')
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>
