# %%
import pandas as pd
data= {
    "Brand" : ["Dell","Lenovo","Dell","HP","Lenovo","Mac Apple","HP","Samsung","Dell","Mac Apple"],
    "Model" : ["latitute 75g","ThinkPad","latitude 80g","Elitebook","L Series","Apple 16 pro","ChromeBook 12","20 Pro", "Dell XPS 15 9500","Macintosh 15 pro"],
    "Previous Price": [120,110,110,50,140,130,170,115,120,105],
    "New Price":[120,120,90,60,150,130,110,130,110,120]
}
df = pd.DataFrame(data)
df
# Out:
#        Brand             Model  Previous Price  New Price
# 0       Dell      latitute 75g             120        120
# 1     Lenovo          ThinkPad             110        120
# 2       Dell      latitude 80g             110         90
# 3         HP         Elitebook              50         60
# 4     Lenovo          L Series             140        150
# 5  Mac Apple      Apple 16 pro             130        130
# 6         HP     ChromeBook 12             170        110
# 7    Samsung            20 Pro             115        130
# 8       Dell  Dell XPS 15 9500             120        110
# 9  Mac Apple  Macintosh 15 pro             105        120

# %%
df[df["Previous Price"] == df["New Price"]]
# Out:
#        Brand         Model  Previous Price  New Price
# 0       Dell  latitute 75g             120        120
# 5  Mac Apple  Apple 16 pro             130        130

# %%
df[df["New Price"] > 100]
# Out:
#        Brand             Model  Previous Price  New Price
# 0       Dell      latitute 75g             120        120
# 1     Lenovo          ThinkPad             110        120
# 4     Lenovo          L Series             140        150
# 5  Mac Apple      Apple 16 pro             130        130
# 6         HP     ChromeBook 12             170        110
# 7    Samsung            20 Pro             115        130
# 8       Dell  Dell XPS 15 9500             120        110
# 9  Mac Apple  Macintosh 15 pro             105        120

# %%
P_total = sum(df['Previous Price'])
print("Previous Price Total is:",P_total)
# Out:
# Previous Price Total is: 1170

# %%
N_total = sum(df['New Price'])
print("New Price Total is:",N_total)
# Out:
# New Price Total is: 1140

# %%
Diff = P_total - N_total
Diff
# Out:
# 30

# %%
df[df['Previous Price'] % 2 == 0]
# Out:
#        Brand             Model  Previous Price  New Price
# 0       Dell      latitute 75g             120        120
# 1     Lenovo          ThinkPad             110        120
# 2       Dell      latitude 80g             110         90
# 3         HP         Elitebook              50         60
# 4     Lenovo          L Series             140        150
# 5  Mac Apple      Apple 16 pro             130        130
# 6         HP     ChromeBook 12             170        110
# 8       Dell  Dell XPS 15 9500             120        110

# %%
df.shape
# Out:
# (10, 4)

# %%
df.values
# Out:
# array([['Dell', 'latitute 75g', 120, 120],
#        ['Lenovo', 'ThinkPad', 110, 120],
#        ['Dell', 'latitude 80g', 110, 90],
#        ['HP', 'Elitebook', 50, 60],
#        ['Lenovo', 'L Series', 140, 150],
#        ['Mac Apple', 'Apple 16 pro', 130, 130],
#        ['HP', 'ChromeBook 12', 170, 110],
#        ['Samsung', '20 Pro', 115, 130],
#        ['Dell', 'Dell XPS 15 9500', 120, 110],
#        ['Mac Apple', 'Macintosh 15 pro', 105, 120]], dtype=object)

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Previous Price', 'New Price'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df
# Out:
#        Brand             Model  Previous Price  New Price
# 0       Dell      latitute 75g             120        120
# 1     Lenovo          ThinkPad             110        120
# 2       Dell      latitude 80g             110         90
# 3         HP         Elitebook              50         60
# 4     Lenovo          L Series             140        150
# 5  Mac Apple      Apple 16 pro             130        130
# 6         HP     ChromeBook 12             170        110
# 7    Samsung            20 Pro             115        130
# 8       Dell  Dell XPS 15 9500             120        110
# 9  Mac Apple  Macintosh 15 pro             105        120

# %%
is_brand = df["Brand"].isin(["Dell", "HP"])
is_brand
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6     True
# 7    False
# 8     True
# 9    False
# Name: Brand, dtype: bool

# %%
df.sort_values(["Previous Price"], ascending=[False])
df
# Out:
#        Brand             Model  Previous Price  New Price
# 0       Dell      latitute 75g             120        120
# 1     Lenovo          ThinkPad             110        120
# 2       Dell      latitude 80g             110         90
# 3         HP         Elitebook              50         60
# 4     Lenovo          L Series             140        150
# 5  Mac Apple      Apple 16 pro             130        130
# 6         HP     ChromeBook 12             170        110
# 7    Samsung            20 Pro             115        130
# 8       Dell  Dell XPS 15 9500             120        110
# 9  Mac Apple  Macintosh 15 pro             105        120
